# %% [markdown]
# # Experiment 1: Benchmarks
#
# - MABSelector

# %%
import numpy as np
import pandas as pd
import os
import glob
import shutil
from IPython.display import clear_output

def get_summary(all_df):
    temp_df = all_df[all_df['iter_num'] == 9999][['exploitation_hits', 'exploration_hits', 'total_hits', 'hs_id', 'hs_group']]
    temp_df['hs_id'] = temp_df['hs_id'] + '_' + temp_df['hs_group']
    top_df = temp_df.groupby('hs_id').mean()
    top_df.columns = [x+'_mean' for x in top_df.columns]
    top_df['total_hits_std'] = temp_df[['total_hits', 'hs_id']].groupby('hs_id').std()
    top_df['run_counts'] = temp_df[['total_hits', 'hs_id']].groupby('hs_id').count()
    top_df = top_df.sort_values('total_hits_mean', ascending=False)
    return top_df

summary_files = glob.glob('../../../aldd_results/params_results_benchmarks/*/*/*/*/')

# %%
cpd_df
# Out:
#     Index ID        Molecule  \
# 0     125467  _PCBA-12004489
# 1     191550   _PCBA-5714738
# 2       1836       _PCBA-727
# 3     367104     _PCBA-61444
# 4     265518     _PCBA-18617
# 5     331155      _PCBA-9873
# 6     122159   _PCBA-3240809
# 7      44025      _PCBA-2513
# 8     158968      _PCBA-2770
# 9     226070      _PCBA-9864
# 10    161637   _PCBA-2218719
# 11    329599  _PCBA-23665760
# 12     96151   _PCBA-5074937
# 13    144367   _PCBA-3613753
# 14    307373   _PCBA-6604165
# 15     30650      _PCBA-1990
# 16    100877      _PCBA-8081
# 17     21888      _PCBA-5943
# 18    339831      _PCBA-9386
# 19     12171     _PCBA-16315
# 20    347374    _PCBA-740558
# 21     86005   _PCBA-1280531
# 22    269104      _PCBA-7628
# 23     82519     _PCBA-14782
# 24    155268     _PCBA-24812
# 25    178557    _PCBA-722392
# 26     40329      _PCBA-7044
# 27    338527      _PCBA-6058
# 28    103086      _PCBA-3776
# 29    239682     _PCBA-24503
# ..       ...             ...
# 66    200990    _PCBA-102678
# 67    332517     _PCBA-46428
# 68    168488    _PCBA-315630
# 69    202388   _PCBA-1489019
# 70     36612     _PCBA-12589
# 71    349595  _PCBA-45479721
# 72    279909   _PCBA-3270059
# 73    312358   _PCBA-2767327
# 74     16906   _PCBA-1471633
# 75    189923   _PCBA-3945419
# 76    276859  _PCBA-24747932
# 77    334299  _PCBA-23641121
# 78     36312   _PCBA-1911034
# 79    112829     _PCBA-55362
# 80     53504  _PCBA-16021271
# 81    378326   _PCBA-3234830
# 82    258151   _PCBA-2729825
# 83    309855   _PCBA-9671478
# 84    124624  _PCBA-46942625
# 85    364808   _PCBA-3235473
# 86     51159    _PCBA-799552
# 87     33751  _PCBA-11521711
# 88    347943     _PCBA-11684
# 89     11320   _PCBA-6020063
# 90    214868   _PCBA-3851498
# 91     39926   _PCBA-3543368
# 92    268905  _PCBA-49790182
# 93    126725   _PCBA-2813350
# 94    139796   _PCBA-5937435
# 95     27989   _PCBA-5170670
#
#                                          rdkit SMILES  \
# 0   CCCNC(=O)c1ccc(Cn2c(=S)[nH]c3c([nH]c4ccc(OC)cc...
# 1                                    S=C1NNC2=NCCCN12
# 2                        ClC1C(Cl)C(Cl)C(Cl)C(Cl)C1Cl
# 3                                              [Co+2]
# 4                                          N#CC(Br)Br
# 5   FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F...
# 6          CC(C)OCCCn1c(=S)[nH]c2ccc(N3CCOCC3)cc2c1=O
# 7                                       C[As](C)(=O)O
# 8                                            Cl[Pt]Cl
# 9                                                N#CN
# 10              COc1cccc(-c2nc(=S)c3c(n2CCCO)CCCC3)c1
# 11                                             [O-]Cl
# 12          O=C(CCn1c(=S)[nH]c2ccccc2c1=O)NCCc1ccccc1
# 13                                 S=c1[nH]cc2cnccn12
# 14   N#[O+].[C-]#N.[C-]#N.[C-]#N.[C-]#N.[C-]#N.[Fe+2]
# 15                                           CC(=O)NO
# 16                                           C1OCOCO1
# 17                                      ClC(Cl)(Cl)Cl
# 18  FC1(F)C(F)(F)C(F)(F)C2(F)C(F)(F)C(F)(F)C(F)(F)...
# 19                                        C=CCSSSCC=C
# 20                              S=c1[nH]ncn1-c1ccccn1
# 21                           S=c1[nH]nc2ccc3ccccc3n12
# 22                                             OB(O)O
# 23                                             O=[Cd]
# 24                                       Cl[In](Cl)Cl
# 25                     S=c1ncnc2n(-c3ccccc3)[nH]cc1-2
# 26                                     C1CCC2CCCCC2C1
# 27                                               NCCS
# 28                                             CC(C)O
# 29                  O=[Cr](=O)([O-])O[Cr](=O)(=O)[O-]
# ..                                                ...
# 66  CCCCC(CC)CN=C(N)NC(N)=NCCCCCCN=C(N)NC(N)=NCC(C...
# 67                               C=CCSC(CC)(CC)C(N)=O
# 68                                   c1cc(C2OCCO2)cs1
# 69                        CCc1nc2ccccc2c2nc3ccccc3n12
# 70                                 CCCCCC[N+](=O)[O-]
# 71                         CCCCCC(O)CCCC(=O)[O-].[H-]
# 72                                S=C1NCC(c2ccccc2)S1
# 73                          Fc1ccc(N2Cc3ccsc3C=N2)cc1
# 74                          Fc1ccc(N=c2ssnc2Cl)c(F)c1
# 75                                  S=C1CC2CCCC(C2)N1
# 76                  c1cc(-c2cc3cc(N4CCOCC4)ccc3o2)cs1
# 77                          S=C1NCCC12C(=S)Nc1ccccc12
# 78                               CCOC=CC(=O)N(C)CCC#N
# 79             NCCCNCCCCNC(=O)C(O)NC(=O)CCCCCCN=C(N)N
# 80         Cc1cccc(N2CCN(c3ncnc4c3nc3n4CCCCC3)CC2C)c1
# 81                        c1cnc(N2CCCC3(CCNCC3)C2)nc1
# 82             CCOC(=O)NNC(=O)NCCCCCCNC(=O)NNC(=O)OCC
# 83                       CCCC=NNC(=O)CCCCC(=O)NN=CCCC
# 84              c1ccc2c(c1)oc1c(-c3cccc4nccn34)cccc12
# 85   CS(=O)(=O)N1CCC2(CCN(c3cccc(-c4ccccc4)c3)CC2)CC1
# 86                         c1ccn2c(c1)nc1c2nc2ccccn21
# 87                            c1ccc2c(N3CCNCC3)nsc2c1
# 88                                    CCC(C)(C)C(=O)O
# 89                                 CCCNC(=O)C=CC(=O)O
# 90                           c1ccc2nc3c(cc2c1)CCCCCC3
# 91     Clc1ccccc1-c1nc2nc3ccccc3nc2n1-c1ccc2c(c1)OCO2
# 92                     c1cnc2c(-c3cccc4nccn34)cccc2c1
# 93                          N#Cc1ccc2nc3c(nc2c1)CCCC3
# 94                        CC(C)C=NN=C(N)N[N+](=O)[O-]
# 95                  Brc1c(-c2ccc3c(c2)OCO3)nc2ncccn12
#
#                                      Morgan FP_2_1024  pcba-aid624173  \
# 0   0000000011000000000000000000000001000000000000...             0.0
# 1   0000100000000000000000000000000000000000000000...             0.0
# 2   0000000000000000000000000000000000000000000000...             0.0
# 3   0000000000000000000000000000000000000000000000...             0.0
# 4   0100000000000000000000000000000000000000001000...             0.0
# 5   0000000000000000000000000000000000000000000000...             0.0
# 6   0100000001000100000000000000000001000000000000...             0.0
# 7   0000000000000000000000000001000001000000000000...             0.0
# 8   0000000000000000000000000000000000000000000000...             1.0
# 9   0000000000000000000000000000000000000000000000...             0.0
# 10  0000100000000001000000000000000101000000000000...             0.0
# 11  0000000000000000000000000000000000000000000000...             0.0
# 12  0000000001000000000001000000000000000000011000...             0.0
# 13  0000000000000000000000000000000000000000000000...             0.0
# 14  0000000000000000000000000000000000000000000000...             0.0
# 15  0000000000000000000000000000000001000000000000...             0.0
# 16  0000000000000000000000000000000000000000000000...             0.0
# 17  0000000000000000000000000000000000000000000000...             0.0
# 18  0000000000000000000000000000000000001000000000...             0.0
# 19  1000000000000000000000000000000000000000000000...             0.0
# 20  0000000000000000000000000000000000000000000000...             0.0
# 21  0000000000000000000000000000000000000000000001...             1.0
# 22  0000000000000000000000000000000000000000000000...             0.0
# 23  0000000000000000000000000000000000000000000000...             0.0
# 24  0000000000000000000000000000000000000000000000...             0.0
# 25  0000000000000000000000000100000000000000000000...             0.0
# 26  0000100000000000000000000000000000000000000000...             0.0
# 27  0000000000000000000000000000000000000000000000...             0.0
# 28  0100000000000000000000000000000001000000000000...             0.0
# 29  0000000000000000000000000000000000000000000000...             0.0
# ..                                                ...             ...
# 66  0100000000000000000000000000000001000000000000...             0.0
# 67  0000000000000000000000000000000001000000000000...             0.0
# 68  0000000000000010000000000000000000000000000000...             0.0
# 69  0000000000000000000000000000000001000000000001...             0.0
# 70  0000000000000000000000000000000001000000000000...             0.0
# 71  0100000000000000000000000000000001000000000000...             0.0
# 72  0000000000000000000000000000000000000000000000...             0.0
# 73  0000000000000010000000000000000000000000000000...             0.0
# 74  0000010000000000001000000000000000000000000000...             1.0
# 75  0000100000000010000000000000000000000001000000...             0.0
# 76  0000000000000010000000000000000000000000000000...             0.0
# 77  0000000000000000000000000000000000001000000000...             0.0
# 78  0000000000000000000000000000000101000000000000...             0.0
# 79  0100000000000000000000000000000001000000010000...             0.0
# 80  0010100000000011000000000100000101000000000000...             0.0
# 81  0000100000000000000000000000000000001000000000...             0.0
# 82  0000000000000000000000000000000001000000000000...             0.0
# 83  0000000000000000001000000000000001000000010000...             0.0
# 84  0001000000000001000000000000000000000000000000...             0.0
# 85  0000000000000001000000000100000001001000000000...             0.0
# 86  0001000000000000000000000000000000000000000000...             0.0
# 87  0000000000000000000000000000000000000000000000...             0.0
# 88  0000000000000000000000000000000001000000000000...             0.0
# 89  0000000000000000000000000000000101000000000000...             0.0
# 90  0010100000000000000000000000000000000000000100...             0.0
# 91  0000000000010000000000000000000000000000000000...             0.0
# 92  0001001000000001000100000000000000000000000000...             0.0
# 93  0000100000000000000000000000000000000000000000...             0.0
# 94  0100000000000000000000000000000001000000000000...             0.0
# 95  0000000000010000000000000000000010000000000000...             0.0
#
#     BT_0.4 ID
# 0        8212
# 1      242303
# 2       52589
# 3      417857
# 4      316271
# 5       28872
# 6        8510
# 7       94778
# 8      209721
# 9      276823
# 10      11336
# 11     380352
# 12       2261
# 13     195120
# 14     358126
# 15      81403
# 16     151630
# 17      72641
# 18     390584
# 19      62924
# 20     398127
# 21     136758
# 22     319857
# 23     133272
# 24     206021
# 25     229310
# 26      91082
# 27      39859
# 28     153839
# 29      42172
# ..        ...
# 66      40822
# 67     383270
# 68     219241
# 69      26109
# 70      87365
# 71     400348
# 72     330662
# 73     363111
# 74      67659
# 75     240676
# 76     327612
# 77     385052
# 78      87065
# 79     163582
# 80       2315
# 81       9523
# 82     308904
# 83     360608
# 84     175377
# 85      24677
# 86     101912
# 87      84504
# 88     398696
# 89      62073
# 90     265621
# 91      90679
# 92     319658
# 93     177478
# 94     190549
# 95      78742
#
# [960 rows x 6 columns]

# %%
glob.glob(summary_files[0]+'/training_data/iter_*.csv')
# Out:
# ['../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_0.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_1.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_10.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_2.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_3.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_4.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_5.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_6.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_7.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_8.csv',
#  '../../../aldd_results/params_results_benchmarks\\benchmark\\MABSelector_0\\1069\\batch_size_384\\/training_data\\iter_9.csv']

# %%
successful_jobs = []
failed_jobs = []

all_0 = []
all_1 = []
all_2 = []
for i, sf in enumerate(summary_files):
    clear_output()
    print('{}/{}'.format(i, len(summary_files)))
    sf_splits = sf.split('\\')
    hs_group = sf_splits[1]
    hs_id = sf_splits[2]
    rf_id = sf_splits[3]
    batch_size = sf_splits[4]
    
    batch_cpds = glob.glob(sf+'iter_*/expl*.csv')
    if len(batch_cpds) > 0:
        cpd_df = pd.concat([pd.read_csv(x) for x in batch_cpds])
    
        if cpd_df.shape[0] == 10*int(batch_size.split('_')[-1]):
            assert cpd_df['Index ID'].unique().shape[0] == 10*int(batch_size.split('_')[-1])
            successful_jobs.append('{}_rf_{}_{}'.format(hs_id, rf_id, batch_size))
        else:
            failed_jobs.append('{}_rf_{}_{}'.format(hs_id, rf_id, batch_size))
            continue
    else:
        failed_jobs.append('{}_rf_{}_{}'.format(hs_id, rf_id, batch_size))
        continue
    
    des_cols = ['iter_num', 
                'exploitation_hits', 'exploitation_max_hits', 'exploitation_batch_size',
                'exploration_hits', 'exploration_max_hits', 'exploration_batch_size',
                'total_hits', 'total_max_hits', 'total_batch_size']
    summary_df = pd.read_csv(sf+'\summary.csv')
    summary_df = summary_df[des_cols]
    summary_df['rf_id'] = rf_id
    summary_df['hs_id'] = hs_id
    summary_df['batch_size'] = int(batch_size.split('_')[-1])
    summary_df['hs_group'] = hs_group
    
    if int(batch_size.split('_')[-1]) == 96:
        all_0.append(summary_df)
    elif int(batch_size.split('_')[-1]) == 384:
        all_1.append(summary_df)
    else:
        all_2.append(summary_df)

all_0 = pd.concat(all_0)
all_1 = pd.concat(all_1)
all_2 = pd.concat(all_2)
all_df = pd.concat([all_0, all_1, all_2])
# Out:
# 43/44
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-276d2e20e53f> in <module>
#      48 all_0 = pd.concat(all_0)
#      49 all_1 = pd.concat(all_1)
# ---> 50 all_2 = pd.concat(all_2)
#      51 all_df = pd.concat([all_0, all_1, all_2])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     260
#     261         if len(objs) == 0:
# --> 262             raise ValueError('No objects to concatenate')
#     263
#     264         if keys is None:
#
# ValueError: No objects to concatenate

# %%
print('Total jobs: {}'.format(len(successful_jobs) + len(failed_jobs)))
print('Failed jobs: {}'.format(len(failed_jobs)))
print('Successful jobs: {}'.format(len(successful_jobs)))

# %%
top_0 = get_top_summary(all_0)
top_0
# Out:
#                          exploitation_hits_mean  exploration_hits_mean  \
# hs_id
# MABSelector_2_benchmark              150.125000                    0.0
# MABSelector_1_benchmark              132.142857                    0.0
# MABSelector_3_benchmark               93.625000                    0.0
# MABSelector_0_benchmark               74.833333                    0.0
#
#                          total_hits_mean  total_hits_std  run_counts
# hs_id
# MABSelector_2_benchmark       150.125000       46.667326           8
# MABSelector_1_benchmark       132.142857       60.283852           7
# MABSelector_3_benchmark        93.625000       82.673087           8
# MABSelector_0_benchmark        74.833333       73.790017           6

# %%
top_1 = get_top_summary(all_1)
top_1
# Out:
#                          exploitation_hits_mean  exploration_hits_mean  \
# hs_id
# MABSelector_2_benchmark              215.200000                    0.0
# MABSelector_1_benchmark              201.000000                    0.0
# MABSelector_3_benchmark              198.200000                    0.0
# MABSelector_0_benchmark              155.666667                    0.0
#
#                          total_hits_mean  total_hits_std  run_counts
# hs_id
# MABSelector_2_benchmark       215.200000       18.539148           5
# MABSelector_1_benchmark       201.000000        0.000000           2
# MABSelector_3_benchmark       198.200000       45.866109           5
# MABSelector_0_benchmark       155.666667       95.259295           3

# %% [markdown]
# ---
# # Experiment 1: Custom CBWS
#
# - Custom cluster based weighted selector strategies

# %%
import numpy as np
import pandas as pd
import os
import glob
import shutil
from IPython.display import clear_output

def get_summary(all_df):
    temp_df = all_df[all_df['iter_num'] == 9999][['exploitation_hits', 'exploration_hits', 'total_hits', 'hs_id', 'hs_group']]
    temp_df['hs_id'] = temp_df['hs_id'] + '_' + temp_df['hs_group']
    top_df = temp_df.groupby('hs_id').mean()
    top_df.columns = [x+'_mean' for x in top_df.columns]
    top_df['total_hits_std'] = temp_df[['total_hits', 'hs_id']].groupby('hs_id').std()
    top_df['run_counts'] = temp_df[['total_hits', 'hs_id']].groupby('hs_id').count()
    top_df = top_df.sort_values('total_hits_mean', ascending=False)
    return top_df

summary_files = glob.glob('../../../aldd_results/params_results_custom_cbws/*/*/*/*/')

# %%
successful_jobs = []
failed_jobs = []

all_0 = []
all_1 = []
all_2 = []
for i, sf in enumerate(summary_files):
    clear_output()
    print('{}/{}'.format(i, len(summary_files)))
    sf_splits = sf.split('\\')
    hs_group = sf_splits[1]
    hs_id = sf_splits[2]
    rf_id = sf_splits[3]
    batch_size = sf_splits[4]
    
    batch_cpds = glob.glob(sf+'iter_*\expl*.csv')
    if len(batch_cpds) > 0:
        cpd_df = pd.concat([pd.read_csv(x) for x in batch_cpds])
    
        if cpd_df.shape[0] == 10*int(batch_size.split('_')[-1]):
            assert cpd_df['Index ID'].unique().shape[0] == 10*int(batch_size.split('_')[-1])
            successful_jobs.append('{}_rf_{}_{}'.format(hs_id, rf_id, batch_size))
        else:
            failed_jobs.append('{}_rf_{}_{}'.format(hs_id, rf_id, batch_size))
            continue
    else:
        failed_jobs.append('{}_rf_{}_{}'.format(hs_id, rf_id, batch_size))
        continue
    
    des_cols = ['iter_num', 
                'exploitation_hits', 'exploitation_max_hits', 'exploitation_batch_size',
                'exploration_hits', 'exploration_max_hits', 'exploration_batch_size',
                'total_hits', 'total_max_hits', 'total_batch_size']
    summary_df = pd.read_csv(sf+'\summary.csv')
    summary_df = summary_df[des_cols]
    summary_df['rf_id'] = rf_id
    summary_df['hs_id'] = hs_id
    summary_df['batch_size'] = int(batch_size.split('_')[-1])
    summary_df['hs_group'] = hs_group
    
    if int(batch_size.split('_')[-1]) == 96:
        all_0.append(summary_df)
    elif int(batch_size.split('_')[-1]) == 384:
        all_1.append(summary_df)
    else:
        all_2.append(summary_df)

all_0 = pd.concat(all_0)
all_1 = pd.concat(all_1)
all_2 = pd.concat(all_2)
all_df = pd.concat([all_0, all_1, all_2])
# Out:
# 68/69
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-276d2e20e53f> in <module>
#      48 all_0 = pd.concat(all_0)
#      49 all_1 = pd.concat(all_1)
# ---> 50 all_2 = pd.concat(all_2)
#      51 all_df = pd.concat([all_0, all_1, all_2])
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     226                        keys=keys, levels=levels, names=names,
#     227                        verify_integrity=verify_integrity,
# --> 228                        copy=copy, sort=sort)
#     229     return op.get_result()
#     230
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     260
#     261         if len(objs) == 0:
# --> 262             raise ValueError('No objects to concatenate')
#     263
#     264         if keys is None:
#
# ValueError: No objects to concatenate

# %%
print('Total jobs: {}'.format(len(successful_jobs) + len(failed_jobs)))
print('Failed jobs: {}'.format(len(failed_jobs)))
print('Successful jobs: {}'.format(len(successful_jobs)))
# Out:
# Total jobs: 69
# Failed jobs: 31
# Successful jobs: 38

# %%
top_0 = get_top_summary(all_0)
top_0
# Out:
#                                              exploitation_hits_mean  \
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws               43.777778
# ClusterBasedWCSelector_custom_2_custom_cbws                0.000000
#
#                                              exploration_hits_mean  \
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws              48.222222
# ClusterBasedWCSelector_custom_2_custom_cbws              63.800000
#
#                                              total_hits_mean  total_hits_std  \
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws             92.0       64.046858
# ClusterBasedWCSelector_custom_2_custom_cbws             63.8       40.900421
#
#                                              run_counts
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws           9
# ClusterBasedWCSelector_custom_2_custom_cbws          10

# %%
top_1 = get_top_summary(all_1)
top_1
# Out:
#                                              exploitation_hits_mean  \
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws                   100.3
# ClusterBasedWCSelector_custom_2_custom_cbws                     0.0
#
#                                              exploration_hits_mean  \
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws              64.200000
# ClusterBasedWCSelector_custom_2_custom_cbws             138.444444
#
#                                              total_hits_mean  total_hits_std  \
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws       164.500000       51.895729
# ClusterBasedWCSelector_custom_2_custom_cbws       138.444444       21.083827
#
#                                              run_counts
# hs_id
# ClusterBasedWCSelector_custom_1_custom_cbws          10
# ClusterBasedWCSelector_custom_2_custom_cbws           9
