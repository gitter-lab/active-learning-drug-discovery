# %%
import numpy as np
import pandas as pd
import os
import glob
from analysis_helper_exp3 import *
from IPython.display import clear_output
# %load_ext autoreload
# %autoreload 2
        
iter_max=50
task_col=None
cluster_col='BT_0.4 ID'

run_threshold=0
hs_params, benchmark_params, custom_params = 3, 4, 1
hs_job_count = hs_params*107*11
benchmark_job_count = benchmark_params*107*11
custom_job_count = custom_params*107*11

root_dir = '../../../aldd_results/params_results_exp3_July_2_2020//params_results\\'
hs_dir = glob.glob(root_dir+'sampled_hyparams/*/*/*/*/')
custom_dir = glob.glob(root_dir+'custom_cbws/*/*/*/*/')
benchmark_dir = glob.glob(root_dir+'benchmarks/*/*/*/*/')

df_from_file = True

if df_from_file:
    cdf = pd.read_csv('./exp3/cdf.csv.gz')

# %%
if not df_from_file:
    all_96_hs, all_384_hs, all_1536_hs, all_df_hs, successful_jobs, failed_jobs = get_results(hs_dir, iter_max, task_col, cluster_col, run_threshold, True)

    print('----------------------------------------------------------------------------')
    print('HS Jobs:')
    print('Total jobs: {}'.format(hs_job_count))
    print('Failed jobs: {}'.format(len(failed_jobs)))
    print('Successful jobs: {}'.format(len(successful_jobs)))

    hs_unique = np.unique(["_".join(x.split('_')[0:2]) for x in successful_jobs])
    print('Total HS: {}'.format(hs_params))
    print('Successful HS: {}'.format(len(hs_unique)))
# Out:
# ----------------------------------------------------------------------------
# HS Jobs:
# Total jobs: 3531
# Failed jobs: 0
# Successful jobs: 3531
# Total HS: 3
# Successful HS: 3

# %%
if not df_from_file:
    all_96_bm, all_384_bm, all_1536_bm, all_df_bm, successful_jobs, failed_jobs = get_results(benchmark_dir, iter_max, task_col, cluster_col, run_threshold, True)

    print('----------------------------------------------------------------------------')
    print('Benchmark Jobs:')
    print('Total jobs: {}'.format(benchmark_job_count))
    print('Failed jobs: {}'.format(len(failed_jobs)))
    print('Successful jobs: {}'.format(len(successful_jobs)))

    hs_unique = np.unique(["_".join(x.split('_')[0:2]) for x in successful_jobs])
    print('Total HS: {}'.format(benchmark_params))
    print('Successful HS: {}'.format(len(hs_unique)))
# Out:
# ----------------------------------------------------------------------------
# Benchmark Jobs:
# Total jobs: 4708
# Failed jobs: 0
# Successful jobs: 4708
# Total HS: 4
# Successful HS: 24

# %%
if not df_from_file:
    all_96_cs, all_384_cs, all_1536_cs, all_df_cs, successful_jobs, failed_jobs = get_results(custom_dir, iter_max, task_col, cluster_col, run_threshold, True)

    print('----------------------------------------------------------------------------')
    print('Custom Jobs:')
    print('Total jobs: {}'.format(custom_job_count))
    print('Failed jobs: {}'.format(len(failed_jobs)))
    print('Successful jobs: {}'.format(len(successful_jobs)))

    hs_unique = np.unique(["_".join(x.split('_')[0:3]) for x in successful_jobs])
    print('Total HS: {}'.format(custom_params))
    print('Successful HS: {}'.format(len(hs_unique)))
# Out:
# ----------------------------------------------------------------------------
# Custom Jobs:
# Total jobs: 1177
# Failed jobs: 0
# Successful jobs: 1177
# Total HS: 1
# Successful HS: 1

# %%
recompute_task_info=False
if recompute_task_info:
    task_names = [r.split('\\')[-2][:-6] for r in glob.glob('../datasets/pcba/*_cv_96/')]
    task_hit_dict = {}
    for task_col in task_names:
        task_df = pd.concat([pd.read_csv(x) for x in glob.glob('../datasets/pcba/{}_cv_96/unlabeled_*.csv'.format(task_col))])
        cpd_count = task_df.shape[0]
        hit_limit = task_df[task_col].sum()
        unique_hit_limit = task_df[task_df[task_col] == 1][cluster_col].unique().shape[0]
        task_hit_dict[task_col] = (hit_limit, unique_hit_limit, cpd_count)
else:
    import pickle
    with open('task_info_dict.pickle', 'rb') as handle:
        task_hit_dict = pickle.load(handle)

# %%
des_cols = ['hs_id', 'rf_id', 'max_iter', 'exploitation_hits', 'exploration_hits', 'total_hits',
            'total_unique_hits', 'total_batch_size', 'hs_group', 'task_col']

if not df_from_file:
    cdf = pd.concat([all_96_hs, all_96_bm, all_96_cs])

hit_limit_list = []
uhit_limit_list = []
cpd_count_list = []
for tcol in cdf['task_col'].tolist():
    a, b, c = task_hit_dict[tcol]
    hit_limit_list.append(a)
    uhit_limit_list.append(b)
    cpd_count_list.append(c)
    
cdf['hit_limit'] = hit_limit_list
cdf['unique_hit_limit'] = uhit_limit_list
cdf['cpd_count'] = cpd_count_list

# %% [markdown]
# ---
# # Summary per 10, 20, 30, 40, 50 iterations

# %%
def helper_agg(col):
    if col.name  in ['rf_id', 'task_col']:
        return '-'
    elif col.name in ['hs_id', 'hs_group']:
        return col.unique()[0]
    else:
        if '_std' in col.name:
            return col.std()
        else:
            return col.mean()

def get_last_iter_summary(results_df, iter_max, group_cols = ['hs_id', 'rf_id']):
    sdf1 = results_df[results_df['iter_num']==iter_max][des_cols]
    sdf1 = sdf1.groupby(group_cols).agg(helper_agg).sort_values('total_hits', ascending=False)
    sorted_hid_list = sdf1.index.tolist()

    sdf2 = results_df[results_df['iter_num']==iter_max][des_cols]
    sdf2 = sdf2[[c for c in sdf2.columns if ('_hits' in c or 'hs_id' in c or 'rf_id' in c)]]
    sdf2.columns = [c.replace('hits', 'std') for c in sdf2.columns]
    sdf2 = sdf2.groupby(group_cols).agg(helper_agg).loc[sorted_hid_list]

    sdf = pd.concat([sdf1, sdf2], axis=1)
    return sdf

# %%
cdf_without_inactives = cdf[cdf['rf_id'] != 'allinactive0']
x = get_last_iter_summary(cdf_without_inactives, 9010, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                  124.229907          0.000000
# MABSelector_2                           119.100000          0.000000
# ClusterBasedWCSelector_341               26.687850         90.093458
# ClusterBasedWCSelector_609                0.000000        103.291589
# ClusterBasedWCSelector_55                 0.000000         93.659813
# ClusterBasedWCSelector_custom_1          27.704673         46.955140
# ClusterBasedRandom                        0.000000         17.931776
# InstanceBasedRandom                       0.000000         14.091589
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_exploitive           124.229907          65.233645  166.288651
# MABSelector_2                    119.100000          61.125234  156.482016
# ClusterBasedWCSelector_341       116.781308          68.445794  152.386886
# ClusterBasedWCSelector_609       103.291589          82.908411  119.634120
# ClusterBasedWCSelector_55         93.659813          82.534579  113.199313
# ClusterBasedWCSelector_custom_1   74.659813          58.816822  106.756361
# ClusterBasedRandom                17.931776          17.892523   32.816781
# InstanceBasedRandom               14.091589          14.028972   28.502458
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                  75.708339
# MABSelector_2                           67.723501
# ClusterBasedWCSelector_341              82.626983
# ClusterBasedWCSelector_609             103.874137
# ClusterBasedWCSelector_55              107.314276
# ClusterBasedWCSelector_custom_1         84.646263
# ClusterBasedRandom                      32.719956
# InstanceBasedRandom                     28.321423

# %%
x = get_last_iter_summary(cdf_without_inactives, 9020, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                  264.916822          0.000000
# MABSelector_2                           250.838318          0.000000
# ClusterBasedWCSelector_341               59.546729        184.933645
# ClusterBasedWCSelector_609                0.000000        217.526168
# ClusterBasedWCSelector_55                 0.000000        195.150467
# ClusterBasedWCSelector_custom_1          75.709346        110.095327
# ClusterBasedRandom                        0.000000         35.863551
# InstanceBasedRandom                       0.000000         28.154206
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_exploitive           264.916822         138.511215  345.194463
# MABSelector_2                    250.838318         126.512150  316.907155
# ClusterBasedWCSelector_341       244.480374         142.113084  306.301711
# ClusterBasedWCSelector_609       217.526168         165.232710  242.726809
# ClusterBasedWCSelector_55        195.150467         167.471028  227.279730
# ClusterBasedWCSelector_custom_1  185.804673         135.769159  243.521326
# ClusterBasedRandom                35.863551          35.741121   65.790239
# InstanceBasedRandom               28.154206          27.930841   56.750727
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                 154.527613
# MABSelector_2                          131.890958
# ClusterBasedWCSelector_341             166.502264
# ClusterBasedWCSelector_609             203.626396
# ClusterBasedWCSelector_55              213.283731
# ClusterBasedWCSelector_custom_1        181.009879
# ClusterBasedRandom                      65.528615
# InstanceBasedRandom                     56.059894

# %%
x = get_last_iter_summary(cdf_without_inactives, 9030, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                  389.485981          0.000000
# MABSelector_2                           367.671963          0.000000
# ClusterBasedWCSelector_341               87.271028        269.742991
# ClusterBasedWCSelector_609                0.000000        319.355140
# ClusterBasedWCSelector_custom_1         124.434579        167.378505
# ClusterBasedWCSelector_55                 0.000000        282.976636
# ClusterBasedRandom                        0.000000         53.726168
# InstanceBasedRandom                       0.000000         42.156075
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_exploitive           389.485981         204.550467  512.089996
# MABSelector_2                    367.671963         186.701869  462.224895
# ClusterBasedWCSelector_341       357.014019         208.042991  450.836411
# ClusterBasedWCSelector_609       319.355140         236.503738  357.910126
# ClusterBasedWCSelector_custom_1  291.813084         206.369159  372.135554
# ClusterBasedWCSelector_55        282.976636         239.835514  332.305494
# ClusterBasedRandom                53.726168          53.448598   98.052375
# InstanceBasedRandom               42.156075          41.633645   85.046275
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                 227.711585
# MABSelector_2                          192.710201
# ClusterBasedWCSelector_341             245.133541
# ClusterBasedWCSelector_609             294.608287
# ClusterBasedWCSelector_custom_1        268.886526
# ClusterBasedWCSelector_55              310.557170
# ClusterBasedRandom                      97.458742
# InstanceBasedRandom                     83.465102

# %%
x = get_last_iter_summary(cdf_without_inactives, 9040, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                  501.789720          0.000000
# MABSelector_2                           472.374766          0.000000
# ClusterBasedWCSelector_341              110.138318        346.612150
# ClusterBasedWCSelector_609                0.000000        410.498131
# ClusterBasedWCSelector_custom_1         170.302804        218.348598
# ClusterBasedWCSelector_55                 0.000000        360.382243
# ClusterBasedRandom                        0.000000         71.388785
# InstanceBasedRandom                       0.000000         56.030841
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_exploitive           501.789720         264.948598  670.734225
# MABSelector_2                    472.374766         240.400935  600.706185
# ClusterBasedWCSelector_341       456.750467         267.042056  584.146244
# ClusterBasedWCSelector_609       410.498131         299.029907  466.900030
# ClusterBasedWCSelector_custom_1  388.651402         269.963551  493.236581
# ClusterBasedWCSelector_55        360.382243         302.608411  427.893713
# ClusterBasedRandom                71.388785          70.915888  130.345092
# InstanceBasedRandom               56.030841          55.057009  113.463667
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                 298.013222
# MABSelector_2                          249.861022
# ClusterBasedWCSelector_341             318.980821
# ClusterBasedWCSelector_609             377.807244
# ClusterBasedWCSelector_custom_1        350.711835
# ClusterBasedWCSelector_55              398.209095
# ClusterBasedRandom                     129.293324
# InstanceBasedRandom                    110.493880

# %%
x = get_last_iter_summary(cdf_without_inactives, 9050, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                  604.433645          0.000000
# MABSelector_2                           569.587850          0.000000
# ClusterBasedWCSelector_341              130.193458        417.948598
# ClusterBasedWCSelector_609                0.000000        493.204673
# ClusterBasedWCSelector_custom_1         212.733645        264.552336
# ClusterBasedWCSelector_55                 0.000000        430.511215
# ClusterBasedRandom                        0.000000         89.419626
# InstanceBasedRandom                       0.000000         70.209346
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_exploitive           604.433645         320.632710  821.195904
# MABSelector_2                    569.587850         291.066355  733.889001
# ClusterBasedWCSelector_341       548.142056         321.110280  710.912387
# ClusterBasedWCSelector_609       493.204673         354.290654  570.581205
# ClusterBasedWCSelector_custom_1  477.285981         327.690654  606.569295
# ClusterBasedWCSelector_55        430.511215         358.271028  518.490409
# ClusterBasedRandom                89.419626          88.700000  162.782973
# InstanceBasedRandom               70.209346          68.673832  141.748189
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                 365.942806
# MABSelector_2                          306.304361
# ClusterBasedWCSelector_341             388.984102
# ClusterBasedWCSelector_609             453.304122
# ClusterBasedWCSelector_custom_1        425.840010
# ClusterBasedWCSelector_55              478.471140
# ClusterBasedRandom                     161.178380
# InstanceBasedRandom                    137.052485

# %% [markdown]
# ---
# # Per task activity ratio
# ### 0 <= actives_ratio <= 0.1

# %%
task_dfs = cdf_without_inactives[cdf_without_inactives['iter_num']==9050]
task_dfs['total_hits_log'] = np.log(task_dfs['total_hits'].values)

task_info = task_dfs[['task_col', 'hit_limit', 'unique_hit_limit', 'cpd_count']].drop_duplicates()
task_info['active_ratio'] = np.around(100.0 * task_info['hit_limit'] / task_info['cpd_count'], decimals=2)
task_info['hit_limit'] = task_info['hit_limit'].astype(int)

lower_thresh, upper_thresh = 0.0, 0.1
qualifying_tasks = task_info[(task_info['active_ratio'] >= lower_thresh) & (task_info['active_ratio'] <= upper_thresh)]['task_col'].tolist()
ldf = task_dfs[task_dfs['task_col'].isin(qualifying_tasks)]
x = get_last_iter_summary(ldf, 9050, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
# C:\Users\Moeman\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#
# C:\Users\Moeman\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                  exploitation_hits  exploration_hits  \
# hs_id
# ClusterBasedWCSelector_341                0.120833         22.700000
# MABSelector_exploitive                   22.662500          0.000000
# MABSelector_2                            22.379167          0.000000
# ClusterBasedWCSelector_609                0.000000         21.595833
# ClusterBasedWCSelector_55                 0.000000         17.320833
# ClusterBasedWCSelector_custom_1           9.641667          6.529167
# ClusterBasedRandom                        0.000000          3.816667
# InstanceBasedRandom                       0.000000          2.683333
#
#                                  total_hits  total_unique_hits  total_std  \
# hs_id
# ClusterBasedWCSelector_341        22.820833          16.662500  21.464118
# MABSelector_exploitive            22.662500          16.129167  21.285238
# MABSelector_2                     22.379167          15.879167  21.010109
# ClusterBasedWCSelector_609        21.595833          16.487500  17.942236
# ClusterBasedWCSelector_55         17.320833          14.208333  13.107584
# ClusterBasedWCSelector_custom_1   16.170833          12.150000  15.200748
# ClusterBasedRandom                 3.816667           3.808333   2.691948
# InstanceBasedRandom                2.683333           2.662500   2.117800
#
#                                  total_unique_std
# hs_id
# ClusterBasedWCSelector_341              15.155493
# MABSelector_exploitive                  14.662307
# MABSelector_2                           14.312632
# ClusterBasedWCSelector_609              13.415155
# ClusterBasedWCSelector_55               10.520270
# ClusterBasedWCSelector_custom_1         10.617464
# ClusterBasedRandom                       2.682021
# InstanceBasedRandom                      2.091688

# %%
lower_thresh, upper_thresh = 0.1, 0.3
qualifying_tasks = task_info[(task_info['active_ratio'] >= lower_thresh) & (task_info['active_ratio'] <= upper_thresh)]['task_col'].tolist()
ldf = task_dfs[task_dfs['task_col'].isin(qualifying_tasks)]
x = get_last_iter_summary(ldf, 9050, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                     125.365             0.000
# MABSelector_2                              121.190             0.000
# ClusterBasedWCSelector_341                   1.915           116.380
# ClusterBasedWCSelector_609                   0.000           115.550
# ClusterBasedWCSelector_55                    0.000            93.900
# ClusterBasedWCSelector_custom_1             50.700            40.555
# ClusterBasedRandom                           0.000            14.950
# InstanceBasedRandom                          0.000             9.695
#
#                                  total_hits  total_unique_hits  total_std  \
# hs_id
# MABSelector_exploitive              125.365             86.860  71.637149
# MABSelector_2                       121.190             84.400  71.863522
# ClusterBasedWCSelector_341          118.295             83.550  68.650509
# ClusterBasedWCSelector_609          115.550             84.405  67.645897
# ClusterBasedWCSelector_55            93.900             74.240  59.527621
# ClusterBasedWCSelector_custom_1      91.255             67.560  66.166608
# ClusterBasedRandom                   14.950             14.905   5.462297
# InstanceBasedRandom                   9.695              9.630   3.687814
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                  44.570540
# MABSelector_2                           44.294810
# ClusterBasedWCSelector_341              43.294336
# ClusterBasedWCSelector_609              43.918277
# ClusterBasedWCSelector_55               43.744374
# ClusterBasedWCSelector_custom_1         43.907468
# ClusterBasedRandom                       5.440032
# InstanceBasedRandom                      3.641345

# %%
lower_thresh, upper_thresh = 0.3, 0.5
qualifying_tasks = task_info[(task_info['active_ratio'] >= lower_thresh) & (task_info['active_ratio'] <= upper_thresh)]['task_col'].tolist()
ldf = task_dfs[task_dfs['task_col'].isin(qualifying_tasks)]
x = get_last_iter_summary(ldf, 9050, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                   260.84375           0.00000
# MABSelector_2                            257.83125           0.00000
# ClusterBasedWCSelector_341                 6.68125         240.43750
# ClusterBasedWCSelector_609                 0.00000         239.79375
# ClusterBasedWCSelector_custom_1          118.88750          88.18125
# ClusterBasedWCSelector_55                  0.00000         200.55625
# ClusterBasedRandom                         0.00000          25.78125
# InstanceBasedRandom                        0.00000          18.04375
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_exploitive            260.84375          166.81875  142.708285
# MABSelector_2                     257.83125          165.37500  140.142615
# ClusterBasedWCSelector_341        247.11875          160.13125  136.771828
# ClusterBasedWCSelector_609        239.79375          161.90625  142.456839
# ClusterBasedWCSelector_custom_1   207.06875          141.12500  145.531346
# ClusterBasedWCSelector_55         200.55625          149.10000  122.271260
# ClusterBasedRandom                 25.78125           25.64375    8.112939
# InstanceBasedRandom                18.04375           17.78750    5.855006
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                  88.279778
# MABSelector_2                           86.113699
# ClusterBasedWCSelector_341              85.696636
# ClusterBasedWCSelector_609              92.956526
# ClusterBasedWCSelector_custom_1         94.722418
# ClusterBasedWCSelector_55               89.843484
# ClusterBasedRandom                       8.054333
# InstanceBasedRandom                      5.726895

# %%
lower_thresh, upper_thresh = 0.5, 0.7
qualifying_tasks = task_info[(task_info['active_ratio'] >= lower_thresh) & (task_info['active_ratio'] <= upper_thresh)]['task_col'].tolist()
ldf = task_dfs[task_dfs['task_col'].isin(qualifying_tasks)]
x = get_last_iter_summary(ldf, 9050, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_2                           418.185714          0.000000
# MABSelector_exploitive                  417.342857          0.000000
# ClusterBasedWCSelector_609                0.000000        394.328571
# ClusterBasedWCSelector_341                8.085714        385.271429
# ClusterBasedWCSelector_custom_1         197.100000        172.557143
# ClusterBasedWCSelector_55                 0.000000        343.657143
# ClusterBasedRandom                        0.000000         42.028571
# InstanceBasedRandom                       0.000000         28.471429
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_2                    418.185714         277.471429  188.926586
# MABSelector_exploitive           417.342857         277.771429  181.750098
# ClusterBasedWCSelector_609       394.328571         275.142857  176.830937
# ClusterBasedWCSelector_341       393.357143         269.014286  179.245442
# ClusterBasedWCSelector_custom_1  369.657143         259.485714  176.479739
# ClusterBasedWCSelector_55        343.657143         264.928571  149.334843
# ClusterBasedRandom                42.028571          41.757143    9.373059
# InstanceBasedRandom               28.471429          28.185714    6.240869
#
#                                  total_unique_std
# hs_id
# MABSelector_2                          110.023413
# MABSelector_exploitive                 105.092943
# ClusterBasedWCSelector_609             111.463166
# ClusterBasedWCSelector_341             108.755609
# ClusterBasedWCSelector_custom_1        113.899872
# ClusterBasedWCSelector_55              110.449847
# ClusterBasedRandom                       9.331939
# InstanceBasedRandom                      6.125009

# %%
lower_thresh, upper_thresh = 0.7, 1.0
qualifying_tasks = task_info[(task_info['active_ratio'] >= lower_thresh) & (task_info['active_ratio'] <= upper_thresh)]['task_col'].tolist()
ldf = task_dfs[task_dfs['task_col'].isin(qualifying_tasks)]
x = get_last_iter_summary(ldf, 9050, ['hs_id'])
x.drop(['rf_id', 'max_iter', 'total_batch_size', 'task_col', 'hs_group', 'exploitation_std', 'exploration_std'], axis=1)
# Out:
#                                  exploitation_hits  exploration_hits  \
# hs_id
# MABSelector_exploitive                     528.875             0.000
# MABSelector_2                              521.875             0.000
# ClusterBasedWCSelector_609                   0.000           506.275
# ClusterBasedWCSelector_341                  12.900           492.950
# ClusterBasedWCSelector_custom_1            218.000           227.425
# ClusterBasedWCSelector_55                    0.000           432.425
# ClusterBasedRandom                           0.000            62.200
# InstanceBasedRandom                          0.000            41.750
#
#                                  total_hits  total_unique_hits   total_std  \
# hs_id
# MABSelector_exploitive              528.875            337.550  189.604878
# MABSelector_2                       521.875            331.850  197.924511
# ClusterBasedWCSelector_609          506.275            345.175  201.319237
# ClusterBasedWCSelector_341          505.850            322.800  183.364783
# ClusterBasedWCSelector_custom_1     445.425            315.525  202.018137
# ClusterBasedWCSelector_55           432.425            331.825  182.634971
# ClusterBasedRandom                   62.200             61.900   17.264459
# InstanceBasedRandom                  41.750             41.225    7.638465
#
#                                  total_unique_std
# hs_id
# MABSelector_exploitive                 118.022803
# MABSelector_2                          122.660580
# ClusterBasedWCSelector_609             143.550918
# ClusterBasedWCSelector_341             118.412404
# ClusterBasedWCSelector_custom_1        150.554188
# ClusterBasedWCSelector_55              152.422134
# ClusterBasedRandom                      17.099708
# InstanceBasedRandom                      7.433422

# %% [markdown]
# ---
# # Still not done. Ignore lower results for now!
# # Plot per Task Performance
#
# ## Total Hits

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context("paper")
sns.set(font_scale=1.5)

task_dfs = cdf[cdf['iter_num']==9999][des_cols + ['hit_limit', 'unique_hit_limit', 'cpd_count']]
task_dfs = task_dfs[task_dfs['max_iter'] == 49]
task_dfs['total_hits_log'] = np.log(task_dfs['total_hits'].values)

task_info = task_dfs[['task_col', 'hit_limit', 'unique_hit_limit', 'cpd_count']].drop_duplicates()
task_info['active_ratio'] = np.around(100.0 * task_info['hit_limit'] / task_info['cpd_count'], decimals=2)
task_info['hit_limit'] = task_info['hit_limit'].astype(int)

run_large_fig = False
if run_large_fig:
    figsize=(50, 16)

    for col in ['cpd_count', 'hit_limit', 'unique_hit_limit', 'active_ratio']:
        task_order = task_info.sort_values(col)['task_col'].tolist()
        task_values = task_info.sort_values(col)[col].values
        g = sns.catplot(x="task_col", y="total_hits", hue="hs_id", data=task_dfs,
                        order=task_order, kind="box", height=10, aspect=3#, scatter_kws={"s": 1}, linestyles='-', height=10, aspect=5.0
                        )
        g.set_xticklabels(rotation=90)
        lw = g.ax.lines[0].get_linewidth() # lw of first line
        plt.setp(g.ax.lines,linewidth=0.5) 
        g.set(xticklabels=task_values)
        plt.title('X-axis sorted by {}.'.format(col))

# %%
col = 'active_ratio'
sorted_df = task_info.sort_values(col)
task_order = sorted_df['task_col'].tolist()
task_values = sorted_df[col].values
hitlimit_values = sorted_df['hit_limit'].values
num_tasks = 107
batch_size = 10

for idx in range(int(np.ceil(num_tasks / batch_size))):
    c_order = task_order[idx*batch_size:(idx+1)*batch_size]
    c_values = task_values[idx*batch_size:(idx+1)*batch_size]
    
    c_df = task_dfs[task_dfs['task_col'].isin(c_order)]
    
    figsize=(22, 6)
    plt.figure(figsize=figsize)
    g = sns.boxplot(x="task_col", y="total_hits", hue="hs_id", data=c_df,
                    order=c_order, width=0.5)
    g.set_xticklabels(c_values, rotation=90)
    lw = g.lines[0].get_linewidth() # lw of first line
    plt.setp(g.lines,linewidth=0.5) 
    g.set(xticklabels=c_values)
    plt.title('X-axis sorted by {}.'.format(col))
    plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
    
    sns.lineplot(x="task_col", y="total_hits", hue="hs_id", data=c_df,
                 order=c_order, width=0.5)
    plt.show()

# %%
col = 'active_ratio'
sorted_df = task_info.sort_values(col)
task_order = sorted_df['task_col'].tolist()
task_values = sorted_df[col].values
hitlimit_values = sorted_df['hit_limit'].values
num_tasks = 107
batch_size = 10

for idx in range(int(np.ceil(num_tasks / batch_size))):
    c_order = task_order[idx*batch_size:(idx+1)*batch_size]
    c_values = task_values[idx*batch_size:(idx+1)*batch_size]
    c_hvalues = hitlimit_values[idx*batch_size:(idx+1)*batch_size]
    
    c_df = task_dfs[task_dfs['task_col'].isin(c_order)]
    
    figsize=(22, 6)
    plt.figure(figsize=figsize)
    g = sns.boxplot(x="task_col", y="total_hits", hue="hs_id", data=c_df,
                    order=c_order, width=0.5)
    g.set_xticklabels(c_hvalues, rotation=90)
    lw = g.lines[0].get_linewidth() # lw of first line
    plt.setp(g.lines,linewidth=0.5) 
    g.set(xticklabels=c_hvalues)
    plt.title('X-axis sorted by {}.'.format(col))
    plt.legend(bbox_to_anchor=(1.01, 1), loc=2, borderaxespad=0.)
    plt.show()

# %% [markdown]
# ## Total Hits Log-scale

# %%
figsize=(50, 16)

for col in ['cpd_count', 'hit_limit', 'unique_hit_limit', 'active_ratio']:
    task_order = task_info.sort_values(col)['task_col'].tolist()
    task_values = task_info.sort_values(col)[col].values
    task_dfs['total_hits_log'] = np.log(task_dfs['total_hits'].values)
    g = sns.catplot(x="task_col", y="total_hits_log", hue="hs_id", kind="point", data=task_dfs,
                    order=task_order, scatter_kws={"s": 1},
                    linestyles='-', height=10, aspect=5.0)
    g.set_xticklabels(rotation=90)
    lw = g.ax.lines[0].get_linewidth() # lw of first line
    plt.setp(g.ax.lines,linewidth=0.5) 
    g.set(xticklabels=task_values)
    plt.title('X-axis sorted by {}.'.format(col))

# %% [markdown]
# ## Total Unique Hits

# %%
figsize=(50, 16)

for col in ['hit_limit', 'unique_hit_limit', 'active_ratio']:
    task_order = task_info.sort_values(col)['task_col'].tolist()
    task_values = task_info.sort_values(col)[col].values
    g = sns.catplot(x="task_col", y="total_unique_hits", hue="hs_id", kind="point", data=task_dfs,
                    order=task_order, scatter_kws={"s": 1},
                    linestyles='-', height=10, aspect=5.0)
    g.set_xticklabels(rotation=90)
    lw = g.ax.lines[0].get_linewidth() # lw of first line
    plt.setp(g.ax.lines,linewidth=0.5) 
    g.set(xticklabels=task_values)
    plt.title('X-axis sorted by {}.'.format(col))

# %% [markdown]
# ---
#
# # Win Comparisons

# %%
def get_win_mat(task_dfs, metric):
    hs_ids = task_dfs['hs_id'].unique()
    task_cols = task_dfs['task_col'].unique()
    comp_mat = np.zeros((len(hs_ids), len(hs_ids), len(task_cols)))

    for task_i in range(len(task_cols)):
        curr_task_df = task_dfs[task_dfs['task_col'] == task_cols[task_i]]
        curr_task_df.index = curr_task_df['hs_id']
        for hs_i in range(len(hs_ids)):
            value_i = curr_task_df.loc[hs_ids[hs_i], metric]
            for hs_j in range(len(hs_ids)):
                value_j = curr_task_df.loc[hs_ids[hs_j], metric]

                if value_i > (1.1*value_j):
                    comp_mat[hs_i, hs_j, task_i] = 1
    
    return comp_mat

comp_mat = get_win_mat(task_dfs, metric='total_hits')
toplist= []
for task_i in range(len(task_cols)):
    winsum = comp_mat[:,:,task_i].sum(axis=1)
    if np.sum(winsum) > 0:
        toplist.append(hs_ids[np.argsort(winsum)[::-1]][0])

u, c = np.unique(toplist, return_counts=True)
u, c, np.sum(c)

# %%
comp_mat = get_win_mat(task_dfs, metric='total_unique_hits')
                
toplist= []
for task_i in range(len(task_cols)):
    winsum = comp_mat[:,:,task_i].sum(axis=1)
    if np.sum(winsum) > 0:
        toplist.append(hs_ids[np.argsort(winsum)[::-1]][0])
    
u, c = np.unique(toplist, return_counts=True)
u, c, np.sum(c)
