# %%
import pandas as pd
import numpy as np
import os
import glob

df = pd.read_csv('../datasets/pcba/pcba_all.csv')
features = df.columns[:6].tolist()
pcba = df.columns[6:].tolist() 

counts = df[pcba].count().sort_values()
sums = df[pcba].sum().loc[counts.index.tolist()]
sums.name, counts.name = 'actives', 'counts'
count_df = pd.concat([counts, sums], axis=1)

# %%
pcba_df = df[features+pcba]
pcba_df = pcba_df[~pcba_df[pcba].isna().all(axis=1)]

from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.SaltRemover import SaltRemover
from rdkit.Chem.FilterCatalog import *

FP_radius=2
FP_size=1024
saltRemover = SaltRemover(defnFilename='../datasets/Salts.txt')
rdkit_mols = pcba_df['SMILES'].astype(str).apply((lambda x: Chem.MolFromSmiles(x)))
rdkit_mols = rdkit_mols.apply((lambda x: saltRemover.StripMol(x)))
pcba_df['rdkit SMILES'] = rdkit_mols.apply((lambda x: Chem.MolToSmiles(x)))
pcba_df['Morgan FP_2_1024'] = rdkit_mols.apply((lambda x: AllChem.GetMorganFingerprintAsBitVect(x, 
                                                                                       radius=FP_radius, 
                                                                                       nBits=FP_size).ToBitString()))

pcba_df['Index ID'] = np.arange(pcba_df.shape[0])
pcba_df = pcba_df[['Index ID', 'Molecule', 'rdkit SMILES',
                   'Morgan FP_2_1024'] + pcba]
pcba_df.to_csv('../datasets/pcba/pcba_all.csv', index=False)

# %% [markdown]
# ---
# # Prepare PCBA Targets

# %%
import pandas as pd
import numpy as np
import os
import glob
import pathlib
from stratify_helper import *
# %load_ext autoreload
# %autoreload 2

random_seed = 20190918
split_size = 96
cluster_col_name = 'BT_0.4 ID'

data_df = pd.read_csv('../datasets/pcba/pcba_all.csv')
pcba = data_df.columns[6:].tolist() 
features = data_df.columns[:6].tolist() 

for task_col_name in pcba:
    output_dir = '../datasets/pcba_alt/{}_cv_{}/'.format(task_col_name, split_size)
    pathlib.Path(output_dir).mkdir(parents=True, exist_ok=True) 
    
    tmp_df = data_df[features+[task_col_name]]
    stratify_target_alt(tmp_df, output_dir, task_col_name, 
                        num_samples=10, num_actives_in_split=1,
                        split_size=split_size, cluster_col_name=cluster_col_name, 
                        random_seed=random_seed)
    print('-------------------------------------------------------------')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Target pcba-aid1030
# Total molecules: 161295, Total active: 15932, Total inactive: 145363, Total clusters: 52402.
# Clusters #: 52402. Singletons #: 23274. Singletons with hits #: 2811.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 160335, Total active: 15922, Total inactive: 144413
# Total molecules: 161295, Total active: 15932, Total inactive: 145363.
# -------------------------------------------------------------
# Target pcba-aid1379
# Total molecules: 196927, Total active: 561, Total inactive: 196366, Total clusters: 56100.
# Clusters #: 56100. Singletons #: 22153. Singletons with hits #: 90.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 195967, Total active: 551, Total inactive: 195416
# Total molecules: 196927, Total active: 561, Total inactive: 196366.
# -------------------------------------------------------------
# Target pcba-aid1452
# Total molecules: 149537, Total active: 178, Total inactive: 149359, Total clusters: 47444.
# Clusters #: 47444. Singletons #: 19891. Singletons with hits #: 47.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 148577, Total active: 168, Total inactive: 148409
# Total molecules: 149537, Total active: 178, Total inactive: 149359.
# -------------------------------------------------------------
# Target pcba-aid1454
# Total molecules: 115847, Total active: 513, Total inactive: 115334, Total clusters: 42229.
# Clusters #: 42229. Singletons #: 19261. Singletons with hits #: 151.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 114887, Total active: 503, Total inactive: 114384
# Total molecules: 115847, Total active: 513, Total inactive: 115334.
# -------------------------------------------------------------
# Target pcba-aid1457
# Total molecules: 202822, Total active: 720, Total inactive: 202102, Total clusters: 57264.
# Clusters #: 57264. Singletons #: 22689. Singletons with hits #: 90.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 201862, Total active: 710, Total inactive: 201152
# Total molecules: 202822, Total active: 720, Total inactive: 202102.
# -------------------------------------------------------------
# Target pcba-aid1458
# Total molecules: 194622, Total active: 5778, Total inactive: 188844, Total clusters: 55326.
# Clusters #: 55326. Singletons #: 22355. Singletons with hits #: 711.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 193662, Total active: 5768, Total inactive: 187894
# Total molecules: 194622, Total active: 5778, Total inactive: 188844.
# -------------------------------------------------------------
# Target pcba-aid1460
# Total molecules: 222659, Total active: 5650, Total inactive: 217009, Total clusters: 58113.
# Clusters #: 58113. Singletons #: 22455. Singletons with hits #: 1417.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 221699, Total active: 5640, Total inactive: 216059
# Total molecules: 222659, Total active: 5650, Total inactive: 217009.
# -------------------------------------------------------------
# Target pcba-aid1461
# Total molecules: 208320, Total active: 2305, Total inactive: 206015, Total clusters: 57299.
# Clusters #: 57299. Singletons #: 22035. Singletons with hits #: 350.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 207360, Total active: 2295, Total inactive: 205065
# Total molecules: 208320, Total active: 2305, Total inactive: 206015.
# -------------------------------------------------------------
# Target pcba-aid1468
# Total molecules: 252185, Total active: 1038, Total inactive: 251147, Total clusters: 61975.
# Clusters #: 61975. Singletons #: 22590. Singletons with hits #: 231.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 251225, Total active: 1028, Total inactive: 250197
# Total molecules: 252185, Total active: 1038, Total inactive: 251147.
# -------------------------------------------------------------
# Target pcba-aid1469
# Total molecules: 272696, Total active: 170, Total inactive: 272526, Total clusters: 65281.
# Clusters #: 65281. Singletons #: 23766. Singletons with hits #: 38.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 271736, Total active: 160, Total inactive: 271576
# Total molecules: 272696, Total active: 170, Total inactive: 272526.
# -------------------------------------------------------------
# Target pcba-aid1471
# Total molecules: 218543, Total active: 293, Total inactive: 218250, Total clusters: 60849.
# Clusters #: 60849. Singletons #: 24346. Singletons with hits #: 56.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 217583, Total active: 283, Total inactive: 217300
# Total molecules: 218543, Total active: 293, Total inactive: 218250.
# -------------------------------------------------------------
# Target pcba-aid1479
# Total molecules: 270316, Total active: 793, Total inactive: 269523, Total clusters: 65230.
# Clusters #: 65230. Singletons #: 23831. Singletons with hits #: 87.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 269356, Total active: 783, Total inactive: 268573
# Total molecules: 270316, Total active: 793, Total inactive: 269523.
# -------------------------------------------------------------
# Target pcba-aid1631
# Total molecules: 259922, Total active: 892, Total inactive: 259030, Total clusters: 62995.
# Clusters #: 62995. Singletons #: 22937. Singletons with hits #: 90.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 258962, Total active: 882, Total inactive: 258080
# Total molecules: 259922, Total active: 892, Total inactive: 259030.
# -------------------------------------------------------------
# Target pcba-aid1634
# Total molecules: 262142, Total active: 154, Total inactive: 261988, Total clusters: 63139.
# Clusters #: 63139. Singletons #: 22858. Singletons with hits #: 22.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 261182, Total active: 144, Total inactive: 261038
# Total molecules: 262142, Total active: 154, Total inactive: 261988.
# -------------------------------------------------------------
# Target pcba-aid1688
# Total molecules: 204281, Total active: 2375, Total inactive: 201906, Total clusters: 57334.
# Clusters #: 57334. Singletons #: 22488. Singletons with hits #: 429.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 203321, Total active: 2365, Total inactive: 200956
# Total molecules: 204281, Total active: 2375, Total inactive: 201906.
# -------------------------------------------------------------
# Target pcba-aid1721
# Total molecules: 290738, Total active: 1087, Total inactive: 289651, Total clusters: 65600.
# Clusters #: 65600. Singletons #: 23242. Singletons with hits #: 162.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 289778, Total active: 1077, Total inactive: 288701
# Total molecules: 290738, Total active: 1087, Total inactive: 289651.
# -------------------------------------------------------------
# Target pcba-aid2100
# Total molecules: 293012, Total active: 1157, Total inactive: 291855, Total clusters: 65333.
# Clusters #: 65333. Singletons #: 23006. Singletons with hits #: 256.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 292052, Total active: 1147, Total inactive: 290905
# Total molecules: 293012, Total active: 1157, Total inactive: 291855.
# -------------------------------------------------------------
# Target pcba-aid2101
# Total molecules: 310187, Total active: 288, Total inactive: 309899, Total clusters: 70197.
# Clusters #: 70197. Singletons #: 25373. Singletons with hits #: 26.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 309227, Total active: 278, Total inactive: 308949
# Total molecules: 310187, Total active: 288, Total inactive: 309899.
# -------------------------------------------------------------
# Target pcba-aid2147
# Total molecules: 192236, Total active: 3473, Total inactive: 188763, Total clusters: 55011.
# Clusters #: 55011. Singletons #: 22001. Singletons with hits #: 795.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 191276, Total active: 3463, Total inactive: 187813
# Total molecules: 192236, Total active: 3473, Total inactive: 188763.
# -------------------------------------------------------------
# Target pcba-aid2242
# Total molecules: 184089, Total active: 715, Total inactive: 183374, Total clusters: 53174.
# Clusters #: 53174. Singletons #: 20826. Singletons with hits #: 104.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 183129, Total active: 705, Total inactive: 182424
# Total molecules: 184089, Total active: 715, Total inactive: 183374.
# -------------------------------------------------------------
# Target pcba-aid2326
# Total molecules: 260751, Total active: 1065, Total inactive: 259686, Total clusters: 63494.
# Clusters #: 63494. Singletons #: 24228. Singletons with hits #: 127.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 259791, Total active: 1055, Total inactive: 258736
# Total molecules: 260751, Total active: 1065, Total inactive: 259686.
# -------------------------------------------------------------
# Target pcba-aid2451
# Total molecules: 273722, Total active: 2005, Total inactive: 271717, Total clusters: 65940.
# Clusters #: 65940. Singletons #: 24444. Singletons with hits #: 459.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 272762, Total active: 1995, Total inactive: 270767
# Total molecules: 273722, Total active: 2005, Total inactive: 271717.
# -------------------------------------------------------------
# Target pcba-aid2517
# Total molecules: 333254, Total active: 1138, Total inactive: 332116, Total clusters: 72084.
# Clusters #: 72084. Singletons #: 25522. Singletons with hits #: 190.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 332294, Total active: 1128, Total inactive: 331166
# Total molecules: 333254, Total active: 1138, Total inactive: 332116.
# -------------------------------------------------------------
# Target pcba-aid2528
# Total molecules: 341585, Total active: 652, Total inactive: 340933, Total clusters: 71194.
# Clusters #: 71194. Singletons #: 24579. Singletons with hits #: 130.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 340625, Total active: 642, Total inactive: 339983
# Total molecules: 341585, Total active: 652, Total inactive: 340933.
# -------------------------------------------------------------
# Target pcba-aid2546
# Total molecules: 278436, Total active: 10556, Total inactive: 267880, Total clusters: 67104.
# Clusters #: 67104. Singletons #: 25462. Singletons with hits #: 1339.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 277476, Total active: 10546, Total inactive: 266930
# Total molecules: 278436, Total active: 10556, Total inactive: 267880.
# -------------------------------------------------------------
# Target pcba-aid2549
# Total molecules: 231654, Total active: 1211, Total inactive: 230443, Total clusters: 61868.
# Clusters #: 61868. Singletons #: 23684. Singletons with hits #: 219.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 230694, Total active: 1201, Total inactive: 229493
# Total molecules: 231654, Total active: 1211, Total inactive: 230443.
# -------------------------------------------------------------
# Target pcba-aid2551
# Total molecules: 270318, Total active: 16671, Total inactive: 253647, Total clusters: 66495.
# Clusters #: 66495. Singletons #: 25490. Singletons with hits #: 1858.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 269358, Total active: 16661, Total inactive: 252697
# Total molecules: 270318, Total active: 16671, Total inactive: 253647.
# -------------------------------------------------------------
# Target pcba-aid2662
# Total molecules: 285346, Total active: 110, Total inactive: 285236, Total clusters: 66010.
# Clusters #: 66010. Singletons #: 23988. Singletons with hits #: 37.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 284386, Total active: 100, Total inactive: 284286
# Total molecules: 285346, Total active: 110, Total inactive: 285236.
# -------------------------------------------------------------
# Target pcba-aid2675
# Total molecules: 248888, Total active: 99, Total inactive: 248789, Total clusters: 60091.
# Clusters #: 60091. Singletons #: 22641. Singletons with hits #: 20.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 247928, Total active: 89, Total inactive: 247839
# Total molecules: 248888, Total active: 99, Total inactive: 248789.
# -------------------------------------------------------------
# Target pcba-aid2676
# Total molecules: 358419, Total active: 1081, Total inactive: 357338, Total clusters: 71334.
# Clusters #: 71334. Singletons #: 23638. Singletons with hits #: 69.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 357459, Total active: 1071, Total inactive: 356388
# Total molecules: 358419, Total active: 1081, Total inactive: 357338.
# -------------------------------------------------------------
# Target pcba-aid411
# Total molecules: 70618, Total active: 1563, Total inactive: 69055, Total clusters: 27830.
# Clusters #: 27830. Singletons #: 15321. Singletons with hits #: 402.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 69658, Total active: 1553, Total inactive: 68105
# Total molecules: 70618, Total active: 1563, Total inactive: 69055.
# -------------------------------------------------------------
# Target pcba-aid463254
# Total molecules: 329208, Total active: 41, Total inactive: 329167, Total clusters: 69735.
# Clusters #: 69735. Singletons #: 24004. Singletons with hits #: 9.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 328248, Total active: 31, Total inactive: 328217
# Total molecules: 329208, Total active: 41, Total inactive: 329167.
# -------------------------------------------------------------
# Target pcba-aid485281
# Total molecules: 314600, Total active: 253, Total inactive: 314347, Total clusters: 67928.
# Clusters #: 67928. Singletons #: 24015. Singletons with hits #: 62.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 313640, Total active: 243, Total inactive: 313397
# Total molecules: 314600, Total active: 253, Total inactive: 314347.
# -------------------------------------------------------------
# Target pcba-aid485290
# Total molecules: 336790, Total active: 938, Total inactive: 335852, Total clusters: 71151.
# Clusters #: 71151. Singletons #: 24537. Singletons with hits #: 144.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 335830, Total active: 928, Total inactive: 334902
# Total molecules: 336790, Total active: 938, Total inactive: 335852.
# -------------------------------------------------------------
# Target pcba-aid485294
# Total molecules: 309795, Total active: 148, Total inactive: 309647, Total clusters: 67327.
# Clusters #: 67327. Singletons #: 23701. Singletons with hits #: 30.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 308835, Total active: 138, Total inactive: 308697
# Total molecules: 309795, Total active: 148, Total inactive: 309647.
# -------------------------------------------------------------
# Target pcba-aid485297
# Total molecules: 310418, Total active: 9128, Total inactive: 301290, Total clusters: 68534.
# Clusters #: 68534. Singletons #: 24119. Singletons with hits #: 823.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 309458, Total active: 9118, Total inactive: 300340
# Total molecules: 310418, Total active: 9128, Total inactive: 301290.
# -------------------------------------------------------------
# Target pcba-aid485313
# Total molecules: 311759, Total active: 7569, Total inactive: 304190, Total clusters: 68627.
# Clusters #: 68627. Singletons #: 24099. Singletons with hits #: 707.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 310799, Total active: 7559, Total inactive: 303240
# Total molecules: 311759, Total active: 7569, Total inactive: 304190.
# -------------------------------------------------------------
# Target pcba-aid485314
# Total molecules: 317082, Total active: 4493, Total inactive: 312589, Total clusters: 67328.
# Clusters #: 67328. Singletons #: 23279. Singletons with hits #: 564.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 316122, Total active: 4483, Total inactive: 311639
# Total molecules: 317082, Total active: 4493, Total inactive: 312589.
# -------------------------------------------------------------
# Target pcba-aid485341
# Total molecules: 327428, Total active: 1729, Total inactive: 325699, Total clusters: 69694.
# Clusters #: 69694. Singletons #: 24090. Singletons with hits #: 142.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 326468, Total active: 1719, Total inactive: 324749
# Total molecules: 327428, Total active: 1729, Total inactive: 325699.
# -------------------------------------------------------------
# Target pcba-aid485349
# Total molecules: 320080, Total active: 618, Total inactive: 319462, Total clusters: 68958.
# Clusters #: 68958. Singletons #: 24018. Singletons with hits #: 76.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 319120, Total active: 608, Total inactive: 318512
# Total molecules: 320080, Total active: 618, Total inactive: 319462.
# -------------------------------------------------------------
# Target pcba-aid485353
# Total molecules: 323054, Total active: 603, Total inactive: 322451, Total clusters: 69208.
# Clusters #: 69208. Singletons #: 23888. Singletons with hits #: 64.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 322094, Total active: 593, Total inactive: 321501
# Total molecules: 323054, Total active: 603, Total inactive: 322451.
# -------------------------------------------------------------
# Target pcba-aid485360
# Total molecules: 218478, Total active: 1485, Total inactive: 216993, Total clusters: 58943.
# Clusters #: 58943. Singletons #: 23216. Singletons with hits #: 281.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 217518, Total active: 1475, Total inactive: 216043
# Total molecules: 218478, Total active: 1485, Total inactive: 216993.
# -------------------------------------------------------------
# Target pcba-aid485364
# Total molecules: 342165, Total active: 10698, Total inactive: 331467, Total clusters: 69726.
# Clusters #: 69726. Singletons #: 23612. Singletons with hits #: 1320.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 341205, Total active: 10688, Total inactive: 330517
# Total molecules: 342165, Total active: 10698, Total inactive: 331467.
# -------------------------------------------------------------
# Target pcba-aid485367
# Total molecules: 326151, Total active: 557, Total inactive: 325594, Total clusters: 69433.
# Clusters #: 69433. Singletons #: 23984. Singletons with hits #: 95.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 325191, Total active: 547, Total inactive: 324644
# Total molecules: 326151, Total active: 557, Total inactive: 325594.
# -------------------------------------------------------------
# Target pcba-aid492947
# Total molecules: 329377, Total active: 80, Total inactive: 329297, Total clusters: 69782.
# Clusters #: 69782. Singletons #: 24024. Singletons with hits #: 19.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 328417, Total active: 70, Total inactive: 328347
# Total molecules: 329377, Total active: 80, Total inactive: 329297.
# -------------------------------------------------------------
# Target pcba-aid493208
# Total molecules: 41636, Total active: 342, Total inactive: 41294, Total clusters: 6865.
# Clusters #: 6865. Singletons #: 1707. Singletons with hits #: 27.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# ...
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 11875, Total active: 150, Total inactive: 11725
# Total molecules: 12835, Total active: 160, Total inactive: 12675.
# -------------------------------------------------------------
# Target pcba-aid887
# Total molecules: 69432, Total active: 1017, Total inactive: 68415, Total clusters: 27954.
# Clusters #: 27954. Singletons #: 15586. Singletons with hits #: 348.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 68472, Total active: 1007, Total inactive: 67465
# Total molecules: 69432, Total active: 1017, Total inactive: 68415.
# -------------------------------------------------------------
# Target pcba-aid891
# Total molecules: 7574, Total active: 1564, Total inactive: 6010, Total clusters: 3560.
# Clusters #: 3560. Singletons #: 2627. Singletons with hits #: 451.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 6614, Total active: 1554, Total inactive: 5060
# Total molecules: 7574, Total active: 1564, Total inactive: 6010.
# -------------------------------------------------------------
# Target pcba-aid899
# Total molecules: 7912, Total active: 1773, Total inactive: 6139, Total clusters: 3672.
# Clusters #: 3672. Singletons #: 2703. Singletons with hits #: 482.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 6952, Total active: 1763, Total inactive: 5189
# Total molecules: 7912, Total active: 1773, Total inactive: 6139.
# -------------------------------------------------------------
# Target pcba-aid902
# Total molecules: 118929, Total active: 1865, Total inactive: 117064, Total clusters: 35908.
# Clusters #: 35908. Singletons #: 17571. Singletons with hits #: 309.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 117969, Total active: 1855, Total inactive: 116114
# Total molecules: 118929, Total active: 1865, Total inactive: 117064.
# -------------------------------------------------------------
# Target pcba-aid903
# Total molecules: 52789, Total active: 338, Total inactive: 52451, Total clusters: 13503.
# Clusters #: 13503. Singletons #: 6499. Singletons with hits #: 74.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 51829, Total active: 328, Total inactive: 51501
# Total molecules: 52789, Total active: 338, Total inactive: 52451.
# -------------------------------------------------------------
# Target pcba-aid904
# Total molecules: 50958, Total active: 528, Total inactive: 50430, Total clusters: 13419.
# Clusters #: 13419. Singletons #: 6528. Singletons with hits #: 68.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 49998, Total active: 518, Total inactive: 49480
# Total molecules: 50958, Total active: 528, Total inactive: 50430.
# -------------------------------------------------------------
# Target pcba-aid912
# Total molecules: 56623, Total active: 453, Total inactive: 56170, Total clusters: 24733.
# Clusters #: 24733. Singletons #: 14395. Singletons with hits #: 167.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 55663, Total active: 443, Total inactive: 55220
# Total molecules: 56623, Total active: 453, Total inactive: 56170.
# -------------------------------------------------------------
# Target pcba-aid914
# Total molecules: 7743, Total active: 221, Total inactive: 7522, Total clusters: 4012.
# Clusters #: 4012. Singletons #: 3006. Singletons with hits #: 29.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 6783, Total active: 211, Total inactive: 6572
# Total molecules: 7743, Total active: 221, Total inactive: 7522.
# -------------------------------------------------------------
# Target pcba-aid915
# Total molecules: 7943, Total active: 421, Total inactive: 7522, Total clusters: 4235.
# Clusters #: 4235. Singletons #: 3175. Singletons with hits #: 218.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 6983, Total active: 411, Total inactive: 6572
# Total molecules: 7943, Total active: 421, Total inactive: 7522.
# -------------------------------------------------------------
# Target pcba-aid924
# Total molecules: 119950, Total active: 1144, Total inactive: 118806, Total clusters: 34668.
# Clusters #: 34668. Singletons #: 16716. Singletons with hits #: 243.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 118990, Total active: 1134, Total inactive: 117856
# Total molecules: 119950, Total active: 1144, Total inactive: 118806.
# -------------------------------------------------------------
# Target pcba-aid925
# Total molecules: 64171, Total active: 39, Total inactive: 64132, Total clusters: 26635.
# Clusters #: 26635. Singletons #: 15351. Singletons with hits #: 18.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 63211, Total active: 29, Total inactive: 63182
# Total molecules: 64171, Total active: 39, Total inactive: 64132.
# -------------------------------------------------------------
# Target pcba-aid926
# Total molecules: 56572, Total active: 345, Total inactive: 56227, Total clusters: 24918.
# Clusters #: 24918. Singletons #: 14583. Singletons with hits #: 115.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 55612, Total active: 335, Total inactive: 55277
# Total molecules: 56572, Total active: 345, Total inactive: 56227.
# -------------------------------------------------------------
# Target pcba-aid927
# Total molecules: 58624, Total active: 60, Total inactive: 58564, Total clusters: 24564.
# Clusters #: 24564. Singletons #: 13570. Singletons with hits #: 24.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 57664, Total active: 50, Total inactive: 57614
# Total molecules: 58624, Total active: 60, Total inactive: 58564.
# -------------------------------------------------------------
# Target pcba-aid938
# Total molecules: 62495, Total active: 1781, Total inactive: 60714, Total clusters: 26547.
# Clusters #: 26547. Singletons #: 15295. Singletons with hits #: 418.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 61535, Total active: 1771, Total inactive: 59764
# Total molecules: 62495, Total active: 1781, Total inactive: 60714.
# -------------------------------------------------------------
# Target pcba-aid995
# Total molecules: 65747, Total active: 699, Total inactive: 65048, Total clusters: 27388.
# Clusters #: 27388. Singletons #: 15611. Singletons with hits #: 202.0
# Split 0: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 1: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 2: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 3: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 4: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 5: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 6: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 7: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 8: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 9: Total molecules: 96, Total active: 1, Total inactive: 95
# Split 10: Total molecules: 64787, Total active: 689, Total inactive: 64098
# Total molecules: 65747, Total active: 699, Total inactive: 65048.
# -------------------------------------------------------------

# %% [markdown]
# ---
# # tar files

# %%
import pandas as pd
import numpy as np
import os
import glob
from IPython.display import clear_output
import pickle

import tarfile

tasks = ['pcba-aid881', 'pcba-aid1454',
         'pcba-aid902', 'pcba-aid924', 'pcba-aid1452', 'pcba-aid1030', 'pcba-aid2242', 'pcba-aid2147',
         'pcba-aid1458', 'pcba-aid1379', 'pcba-aid540276', 'pcba-aid1457', 'pcba-aid1688',
         'pcba-aid1461', 'pcba-aid485360', 'pcba-aid1471', 'pcba-aid1460', 'pcba-aid2549',
         'pcba-aid504467', 'pcba-aid2675', 'pcba-aid1468', 'pcba-aid1631', 'pcba-aid2326',
         'pcba-aid1634', 'pcba-aid1479', 'pcba-aid2551', 'pcba-aid1469', 'pcba-aid2451',
         'pcba-aid2546', 'pcba-aid720579', 'pcba-aid2662', 'pcba-aid504444', 'pcba-aid1721',
         'pcba-aid624296', 'pcba-aid2100', 'pcba-aid504332', 'pcba-aid686978', 'pcba-aid624287',
         'pcba-aid504706', 'pcba-aid686979', 'pcba-aid720580', 'pcba-aid624297', 'pcba-aid485294',
         'pcba-aid2101', 'pcba-aid485297', 'pcba-aid504466', 'pcba-aid485313', 'pcba-aid485281',
         'pcba-aid485314', 'pcba-aid485349', 'pcba-aid652105', 'pcba-aid485353', 'pcba-aid651965',
         'pcba-aid624288', 'pcba-aid504842', 'pcba-aid624417', 'pcba-aid504333', 'pcba-aid485367',
         'pcba-aid588342', 'pcba-aid485341', 'pcba-aid463254', 'pcba-aid492947', 'pcba-aid624291',
         'pcba-aid2517', 'pcba-aid485290', 'pcba-aid686970', 'pcba-aid720553', 'pcba-aid2528',
         'pcba-aid485364', 'pcba-aid720551', 'pcba-aid651635', 'pcba-aid720504', 'pcba-aid588855',
         'pcba-aid720709', 'pcba-aid651644', 'pcba-aid504339', 'pcba-aid588590', 'pcba-aid720542',
         'pcba-aid720708', 'pcba-aid651768', 'pcba-aid2676', 'pcba-aid504891', 'pcba-aid652106',
         'pcba-aid720707', 'pcba-aid720711', 'pcba-aid652025', 'pcba-aid624246', 'pcba-aid624202',
         'pcba-aid743255', 'pcba-aid588453', 'pcba-aid540317', 'pcba-aid504327',
         'pcba-aid504845', 'pcba-aid588591', 'pcba-aid602313', 'pcba-aid652104', 'pcba-aid588795',
         'pcba-aid602233', 'pcba-aid504847', 'pcba-aid588456', 'pcba-aid602179', 'pcba-aid588579',
         'pcba-aid602310', 'pcba-aid624171', 'pcba-aid624170', 'pcba-aid743266', 'pcba-aid602332']

for task_i, task_col_name in enumerate(tasks):
    clear_output()
    print('{}/{}'.format(task_i, len(tasks)))
    output_dir = '../datasets/pcba_alt/tars/{}_cv_{}.tar.gz'.format(task_col_name, split_size)
    
    tar = tarfile.open(output_dir, "w:gz")
    tar.add('../datasets/pcba_alt/{}_cv_{}/'.format(task_col_name, split_size), 
            arcname='pcba/{}_cv_{}/'.format(task_col_name, split_size))
    tar.close()
# Out:
# 106/107

# %%
import pandas as pd
import numpy as np
import os
import glob
import pathlib
from stratify_helper import *
# %load_ext autoreload
# %autoreload 2

random_seed = 20190918
split_size = 96
cluster_col_name = 'BT_0.4 ID'

data_df = pd.read_csv('../datasets/pcba/pcba_all.csv')
pcba = data_df.columns[6:].tolist() 
features = data_df.columns[:6].tolist() 

for task_col_name in pcba:
    np.random.seed(random_seed)
    
    output_dir = '../datasets/pcba_alt/{}_cv_{}/'.format(task_col_name, split_size)
    pathlib.Path(output_dir).mkdir(parents=True, exist_ok=True) 
    
    tmp_df = data_df[features+[task_col_name]].copy()
    
    tmp_df = tmp_df[~pd.isna(tmp_df[task_col_name])]
    tmp_df = tmp_df.sort_values('Index ID')
    tmp_df = tmp_df.dropna()
    tmp_df = tmp_df.reset_index(drop=True)
    
    inactive_indices = np.where(tmp_df[task_col_name] == 0)[0]

    curr_indices = np.random.choice(inactive_indices, size=96, replace=False)
    assert np.unique(curr_indices).shape[0] == 96
    
    curr_split_df = tmp_df.iloc[curr_indices,:]
    assert curr_split_df[task_col_name].sum() == 0
    
    curr_split_df.to_csv(output_dir+'/unlabeled_allinactive0.csv', 
                         index=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
